# %% [markdown]
# # HOMEWORK 14
#
# In this homework we will be working with the Fashion MNIST dataset. You will be given a classifier which suffers from considerable overfitting. Your objective will be to employ regularization techniques to mitigate the overfitting problem.
#
# Let's start with the usual imports.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras import Model
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

# %% [markdown]
# ### Dataset
#
# The MNIST fashgion dataset [link](https://github.com/zalandoresearch/fashion-mnist) was build by Zalando Reasearch tem consists of monochrome images of different type of clothing, namely:
# * 0	T-shirt/top
# * 1	Trouser
# * 2	Pullover
# * 3	Dress
# * 4	Coat
# * 5	Sandal
# * 6	Shirt
# * 7	Sneaker
# * 8	Bag
# * 9	Ankle boot
#
# It is also one of the Keras built-in datasets. Let's load the images and quickly inspect it.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Dataset params
num_classes = 10
size = x_train.shape[1]

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Train set:    60000 samples
# Test set:     10000 samples
# Sample dims:  (60000, 28, 28)

# %% [markdown]
# Let's visualise some random samples.

# %%
cnt = 1
for r in range(3):
    for c in range(6):
        idx = np.random.randint(len(x_train))
        plt.subplot(3,6,cnt)
        plt.imshow(x_train[idx, ...], cmap='gray')
        plt.title(y_train[idx])
        cnt = cnt + 1

# %% [markdown]
# ### Building the Classifier
#
# We are now going to build the baseline classifier that you will use throughout this homework.

# %%
# Data normalization
x_train = x_train/255
x_test = x_test/255

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,211,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,213,002 (12.26 MB)
#  Trainable params: 3,213,002 (12.26 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 17s 17ms/step - accuracy: 0.8632 - loss: 0.3947 - val_accuracy: 0.8828 - val_loss: 0.3244
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.9047 - loss: 0.2643 - val_accuracy: 0.8906 - val_loss: 0.3064
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.9204 - loss: 0.2238 - val_accuracy: 0.8924 - val_loss: 0.3079
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 30s 32ms/step - accuracy: 0.9302 - loss: 0.1951 - val_accuracy: 0.8956 - val_loss: 0.3113
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9389 - loss: 0.1704 - val_accuracy: 0.8947 - val_loss: 0.3247
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 31s 33ms/step - accuracy: 0.9479 - loss: 0.1487 - val_accuracy: 0.8933 - val_loss: 0.3484
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 27s 29ms/step - accuracy: 0.9549 - loss: 0.1297 - val_accuracy: 0.8904 - val_loss: 0.3727
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━
50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 30s 32ms/step - accuracy: 0.9896 - loss: 0.0293 - val_accuracy: 0.8783 - val_loss: 1.0328
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 28ms/step - accuracy: 0.9906 - loss: 0.0282 - val_accuracy: 0.8821 - val_loss: 0.9660
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 28ms/step - accuracy: 0.9898 - loss: 0.0287 - val_accuracy: 0.8844 - val_loss: 0.9891
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 28s 30ms/step - accuracy: 0.9901 - loss: 0.0267 - val_accuracy: 0.8806 - val_loss: 1.0133
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 50s 39ms/step - accuracy: 0.9909 - loss: 0.0250 - val_accuracy: 0.8814 - val_loss: 1.0819
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 30s 32ms/step - accuracy: 0.9916 - loss: 0.0230 - val_accuracy: 0.8811 - val_loss: 1.1293
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 27s 29ms/step - accuracy: 0.9914 - loss: 0.0233 - val_accuracy: 0.8823 - val_loss: 1.1072
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 24s 26ms/step - accuracy: 0.9919 - loss: 0.0237 - val_accuracy: 0.8808 - val_loss: 1.1365
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 23s 25ms/step - accuracy: 0.9927 - loss: 0.0212 - val_accuracy: 0.8845 - val_loss: 1.1301
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 24s 26ms/step - accuracy: 0.9915 - loss: 0.0246 - val_accuracy: 0.8823 - val_loss: 1.1631
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 25s 26ms/step - accuracy: 0.9927 - loss: 0.0218 - val_accuracy: 0.8818 - val_loss: 1.1886
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 24s 25ms/step - accuracy: 0.9919 - loss: 0.0230 - val_accuracy: 0.8796 - val_loss: 1.2277
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 27s 29ms/step - accuracy: 0.9931 - loss: 0.0195 - val_accuracy: 0.8797 - val_loss: 1.2318
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 25s 26ms/step - accuracy: 0.9935 - loss: 0.0187 - val_accuracy: 0.8817 - val_loss: 1.2475
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 27s 29ms/step - accuracy: 0.9924 - loss: 0.0210 - val_accuracy: 0.8806 - val_loss: 1.2529
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 28s 30ms/step - accuracy: 0.9926 - loss: 0.0222 - val_accuracy: 0.8823 - val_loss: 1.2778
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 25s 27ms/step - accuracy: 0.9934 - loss: 0.0185 - val_accuracy: 0.8786 - val_loss: 1.2853
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 23s 25ms/step - accuracy: 0.9937 - loss: 0.0168 - val_accuracy: 0.8793 - val_loss: 1.3200
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 28s 29ms/step - accuracy: 0.9924 - loss: 0.0219 - val_accuracy: 0.8843 - val_loss: 1.3041
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 29s 31ms/step - accuracy: 0.9940 - loss: 0.0176 - val_accuracy: 0.8856 - val_loss: 1.2835

# %%
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])
        
    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])
    
plot_history(history)
# Out:
# Train Acc      0.9939666390419006
# Validation Acc 0.8855999708175659

# %% [markdown]
# As you can see, the classifier suffers from massive overfitting. The validation accuracy is around 88% while the training accuracy is close to 1.

# %% [markdown]
# ### Combat the Overfitting!
#
# Now it is your turn. Use the classifier as a baseline, include some regularization techniques and try to improve the classification performance. You can try any techniques you might see fit, e.g.,
# * Dropout
# * Batch normalization
# * Weight regularization
# * Data augmentation
# * Early stopping
# * Pooling
# * Reducing the number of parameters (the size of the network)
# * ...
#
# There are to objective you shall fulfill in order to successfully complete this homework:
# * The validation accuracy shall be above 91%
# * Your network (with all the regularizations applied) shall **not** be larger than the baseline

# %%
# Modify the baseline classifier in order to reduce the overfitting and make the performance more robust
from tensorflow.keras import regularizers

inputs = Input(shape=(28, 28, 1))

net = Conv2D(32, (3, 3), activation='relu', padding='same',
             kernel_regularizer=regularizers.l2(0.001))(inputs)
net = BatchNormalization()(net)
net = MaxPooling2D((2, 2))(net)
net = Dropout(0.25)(net)
net = Flatten()(net)
net = Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001))(net)
net = Dropout(0.5)(net)

outputs = Dense(10, activation='softmax')(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 28, 28, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 6272)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │         802,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 804,682 (3.07 MB)
#  Trainable params: 804,618 (3.07 MB)
#  Non-trainable params: 64 (256.00 B)

# %%
# Train the network

epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - accuracy: 0.8176 - loss: 0.7390 - val_accuracy: 0.8791 - val_loss: 0.5269
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - accuracy: 0.8638 - loss: 0.5635 - val_accuracy: 0.8883 - val_loss: 0.4898
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - accuracy: 0.8725 - loss: 0.5429 - val_accuracy: 0.8896 - val_loss: 0.4866
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - accuracy: 0.8755 - loss: 0.5372 - val_accuracy: 0.8935 - val_loss: 0.4878
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 27s 29ms/step - accuracy: 0.8788 - loss: 0.5348 - val_accuracy: 0.8988 - val_loss: 0.4852
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - accuracy: 0.8792 - loss: 0.5279 - val_accuracy: 0.8987 - val_loss: 0.4850
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 27ms/step - accuracy: 0.8805 - loss: 0.5260 - val_accuracy: 0.8944 - val_loss: 0.4816
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - accuracy: 0.8825 - loss: 0.5230 - val_accuracy: 0.8978 - val_loss: 0.4861
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 28ms/step - accuracy: 0.8835 - loss: 0.5193 - val_accuracy: 0.8910 - val_loss: 0.4961
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.8854 - loss: 0.5152 - val_accuracy: 0.8934 - val_loss: 0.4844
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 22s 23ms/step - accuracy: 0.8863 - loss: 0.5107 - val_accuracy: 0.8972 - val_loss: 0.4740
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━
50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 23s 24ms/step - accuracy: 0.8883 - loss: 0.5033 - val_accuracy: 0.8996 - val_loss: 0.4704
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 25s 26ms/step - accuracy: 0.8888 - loss: 0.4950 - val_accuracy: 0.8971 - val_loss: 0.4797
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 24s 26ms/step - accuracy: 0.8897 - loss: 0.4924 - val_accuracy: 0.8982 - val_loss: 0.4739
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 22s 24ms/step - accuracy: 0.8921 - loss: 0.4913 - val_accuracy: 0.9018 - val_loss: 0.4605
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.8901 - loss: 0.4928 - val_accuracy: 0.8970 - val_loss: 0.4763
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 24s 26ms/step - accuracy: 0.8904 - loss: 0.4974 - val_accuracy: 0.8945 - val_loss: 0.4737
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 25s 27ms/step - accuracy: 0.8907 - loss: 0.4952 - val_accuracy: 0.9000 - val_loss: 0.4648
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 24s 25ms/step - accuracy: 0.8900 - loss: 0.4937 - val_accuracy: 0.8946 - val_loss: 0.4777
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.8913 - loss: 0.4925 - val_accuracy: 0.8981 - val_loss: 0.4796
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 23s 25ms/step - accuracy: 0.8905 - loss: 0.4985 - val_accuracy: 0.8989 - val_loss: 0.4704
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 24s 26ms/step - accuracy: 0.8908 - loss: 0.4934 - val_accuracy: 0.8980 - val_loss: 0.4685
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 24s 26ms/step - accuracy: 0.8901 - loss: 0.4927 - val_accuracy: 0.8978 - val_loss: 0.4746
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 24s 26ms/step - accuracy: 0.8899 - loss: 0.4920 - val_accuracy: 0.8956 - val_loss: 0.4805
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 27ms/step - accuracy: 0.8904 - loss: 0.4905 - val_accuracy: 0.9006 - val_loss: 0.4666
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 30s 32ms/step - accuracy: 0.8900 - loss: 0.4900 - val_accuracy: 0.9024 - val_loss: 0.4653
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 29s 31ms/step - accuracy: 0.8908 - loss: 0.4947 - val_accuracy: 0.8999 - val_loss: 0.4626

# %%
# Show the results
plot_history(history)
# Out:
# Train Acc      0.8908166885375977
# Validation Acc 0.8999000191688538

# %% [markdown]
# ### Questions
#
# * What have you done in order to improve the performance?
#
# I've implemented the following techniques:
# 1. Dropout
# * Dropout randomly deactivates neurons during training to make the network more robust.
# 2. Batch Normalization
# * Batch Normalization works as a regularizer: it introduces a slight, inherent noise. This noise acts as a mild regularization, similar to dropout, making it harder for the model to overfit the training data.
# 3. Weight Regularization
# * This technique adds penalties to the layer weights to discourage overly large values.
# 4. Pooling.
# * Pooling reduces spatial size, which decreases parameters and improves generalization.
#
# I can't say that I achived validation accuracy 0.91, but at least the validation accuracy and the training accuracy are almost the same now (around 0,89), meaning that network is not overfitted anymore.
#
# * Have you tried configurations that did not work out?
#
# Yes, at first I've tried to do the network more complex with several layers like Conv2D, MaxPooling2D and BatchNormalization and Dropout accordingly. However, the process of education got waaaay more longer, and secondly, I've achived even lower validation accuracy comparing to the network structure provided as an example.
