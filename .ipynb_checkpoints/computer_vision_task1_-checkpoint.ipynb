# %%
import numpy as n
import cv2
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]

# %%
# Load an image (you can freely chose any image you like)
img = cv2.imread('test.png')
# Convert it to RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Plot it
plt.imshow(img_rgb)

img_rgb.shape
# Out:
# (855, 1153, 3)

# %%
# Split the image into the three colour channels
red, green, blue = cv2.split(img_rgb)

# Compose the image in the RGB colour space
img1 = cv2.merge([red, green, blue])
plt.imshow(img1)

# %%
# Compose the image in the RBG colour space
img2 = cv2.merge([red, green, blue])

# Compose the image in the GRB colour space
img3 = cv2.merge([green, red, blue])

# Compose the image in the BGR colour space
img4 = cv2.merge([blue, green, red])

# Create the collage
out1 = np.hstack([img1, img2])
out2 = np.hstack([img3, img4])
out = np.vstack([out1, out2])

# Plot the collage
plt.imshow(out)
plt.axis(False)
# Out:
# (np.float64(-0.5), np.float64(2305.5), np.float64(1709.5), np.float64(-0.5))

# %%
# Load an image (you can freely chose any image you like)
img = cv2.imread('test2.png')
# Convert it to RGB
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Make a collage
img2 = np.fliplr(img1)
img3 = np.flipud(img1)
img4 = np.fliplr(img3)

# Create the collage
out1 = np.hstack([img1, img2])
out2 = np.hstack([img3, img4])
out = np.vstack([out1, out2])

# Plot the collage
plt.imshow(out)
plt.axis(False)
# Out:
# (np.float64(-0.5), np.float64(1305.5), np.float64(841.5), np.float64(-0.5))
